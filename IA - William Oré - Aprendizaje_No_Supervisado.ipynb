# %% [markdown]
# # Aprendizaje No-Supervisado

# %% [markdown]
# Recordemos que el proposito del aprendizaje automatico superviado es predecir la realidad. El aprendizaje no supervisado tiene como proposito clasificar la realidad y generar predicciones sobre esta clasificacion. El aprendizaje no supervisado clasifica por similaridad.
#
# La principal ventaja del aprendizaje no supervisado es que no se necesitan series de datos etiquetadas para proceder a la clasificacion.
#
# La gran mayoria de modelos de aprendizaje no supervisado utilizan tecnicas de agrupacion por similaridad (distancia) entre parametros.

# %% [markdown]
# Vamos a necesitar los siguientes modulos:

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
sns.set()
# %matplotlib inline

# %% [markdown]
# Generamos un grupo de puntos utilizando la funcion make_blobs:

# %%
puntos, idx_grupos = make_blobs(n_samples=300,
                                centers=4,
                                cluster_std=0.8,
                                random_state=0)
 
x = puntos[:, 0]
y = puntos[:, 1]
 
plt.figure(figsize=(6, 4), dpi=80)
plt.scatter(x, y, s=50, alpha=0.7);

# %%
puntos
# Out:
# array([[ 0.43071995,  2.54925795],
#        [-1.4687922 ,  7.26767764],
#        [ 1.21486062,  5.36489604],
#        [-0.94206983,  7.80806619],
#        [ 1.01004604,  2.2241682 ],
#        [ 3.89840088,  0.049651  ],
#        [-1.90199536,  1.15672923],
#        [ 1.55954253,  4.40697366],
#        [ 0.14284237,  8.63097553],
#        [-0.53204756,  8.93543127],
#        [-1.77419557,  2.73110893],
#        [-3.1439253 ,  8.52670186],
#        [ 1.33136066,  4.57072679],
#        [-2.5543634 ,  6.58124584],
#        [ 1.25509524, -0.33815322],
#        [ 0.27963236,  3.8407076 ],
#        [ 1.10022802,  4.60631734],
#        [ 2.74073201,  0.37684319],
#        [-0.91357347,  3.20291652],
#        [-0.92915335,  1.9667263 ],
#        [ 2.9349952 ,  1.42187464],
#        [ 1.68439074,  1.28284884],
#        [ 0.65372852,  5.28174338],
#        [-2.15300734,  2.82957082],
#        [-2.04873889,  2.50093081],
#        [-1.06612177,  4.8266822 ],
#        [ 1.57821629,  0.85560982],
#        [ 0.46759322,  4.84493396],
#        [-3.3313554 ,  2.09987679],
#        [-0.07645585,  3.93451964],
#        [-0.26835932,  7.8873449 ],
#        [-2.32659611,  7.22620131],
#        [ 2.17153334,  4.13966072],
#        [-1.09220002,  6.41020973],
#        [-1.77630083,  7.97611518],
#        [-2.80969906,  7.30754663],
#        [-2.27200711,  7.36711505],
#        [-3.07915181,  8.03664755],
#        [-2.42836466,  2.33334006],
#        [ 1.53334066,  0.58490096],
#        [ 0.56762597,  3.35928158],
#        [-2.13821915,  1.76764908],
#        [-0.38874607,  5.86440764],
#        [ 1.73407165,  4.17977925],
#        [-1.7603739 ,  2.30868849],
#        [-0.853599  ,  2.7183154 ],
#        [-1.42181543,  8.19177462],
#        [-1.56064117,  2.68837251],
#        [-1.55597211,  7.48039114],
#        [ 1.966835  ,  1.71380183],
#        [-2.09066423,  3.67249084],
#        [ 2.58837399,  0.52908783],
#        [-0.77635192,  7.54437297],
#        [ 1.57741467,  0.70732628],
#        [ 1.65684156,  2.4412893 ],
#        [-0.97188549,  2.79022351],
#        [ 0.36074957,  7.79978367],
#        [-1.01225244,  1.66138353],
#        [-1.99238098,  7.69258874],
#        [ 1.17176085,  0.93939572],
#        [-2.59323035,  7.12428293],
#        [ 0.43680395,  4.32925177],
#        [-1.65050914,  9.76542296],
#        [-0.87528816,  2.96502273],
#        [-2.30378767,  3.16973602],
#        [-1.07307179,  2.73974218],
#        [-2.86138108,  7.40389631],
#        [ 2.47438034,  0.96840133],
#        [-3.13959483,  7.85172736],
#        [-1.48730803,  3.31295168],
#        [ 1.43754273,  4.13714832],
#        [-0.14072706,  3.46548315],
#        [-0.96683169,  8.13884844],
#        [-1.63098958,  2.99304484],
#        [-1.49599957,  1.59251018],
#        [-0.63113102,  8.65901108],
#        [-1.83480786,  2.99336353],
#        [ 1.2613632 ,  4.86904586],
#        [ 2.16883005,  0.64220093],
#        [-0.96444962,  8.32896926],
#        [ 0.98786074, -0.17971034],
#        [ 0.4688124 ,  4.01359439],
#        [ 1.02098199,  1.11130436],
#        [ 1.62097834,  1.2305037 ],
#        [-0.84930355,  8.67383774],
#        [ 0.92167679,  5.6744615 ],
#        [ 2.47388885,  0.76042659],
#        [ 0.2460123 ,  5.19740036],
#        [-2.3140251 ,  6.26056026],
#        [-1.5262163 ,  7.37044523],
#        [ 0.38046622,  3.6426365 ],
#        [ 1.69084152,  0.91164699],
#        [-2.19158212,  8.87660247],
#        [-1.81865885,  3.04324535],
#        [-1.06408682,  3.19760583],
#        [ 1.22672424,  3.62051074],
#        [ 1.13032158,  1.52262214],
#        [ 2.78341065,  1.15143823],
#        [ 0.03777135,  5.85868428],
#        [-3.6542418 ,  3.40293788],
#        [-0.3680283 ,  8.87387759],
#        [ 1.5403728 , -0.88105886],
#        [-0.49428128,  7.62138422],
#        [ 2.47211942,  0.43703328],
#        [ 1.07779975,  4.62537882],
#        [ 2.28434247,  1.38473873],
#        [ 2.56737274, -0.39590118],
#        [ 1.46753357,  5.04155266],
#        [-1.3366473 ,  6.50690017],
#        [ 0.9846701 ,  5.73248372],
#        [-0.90830163,  1.97077775],
#        [-1.63386526,  3.78007731],
#        [ 1.41253979,  0.34602384],
#        [-2.48859925,  8.16931507],
#        [ 1.75992205,  0.70616032],
#        [ 2.48279064,  3.22558008],
#        [-1.77509815,  7.42407284],
#        [ 0.7889168 ,  1.38596716],
#        [ 1.46361712,  2.13207534],
#        [ 0.28728953,  5.83183929],
#        [-0.20839607,  3.04926447],
#        [ 1.55279747,  0.51284197],
#        [-0.84056487,  3.83076375],
#        [ 1.10418012,  0.49221058],
#        [ 1.21906483,  1.86657989],
#        [ 2.04165119,  1.20098505],
#        [ 1.5453179 ,  0.57984621],
#        [-1.30255065,  2.12338337],
#        [ 0.82262991,  0.94827326],
#        [-1.80964941,  1.62470291],
#        [-0.03759331,  8.27796567],
#        [-1.67494695,  2.27176347],
#        [-1.74109084,  2.0154732 ],
#        [ 2.55545268, -0.38398246],
#        [-1.4238886 ,  6.96823072],
#        [-1.16097153,  2.14619265],
#        [-2.68413177,  3.55812062],
#        [-2.37302611,  7.3634139 ],
#        [ 0.32575305,  2.92276125],
#        [-0.30315289,  7.32993701],
#        [-3.03993902,  8.15665926],
#        [-0.88645217,  2.9804904 ],
#        [ 1.34880003,  3.07479238],
#        [-1.65303763,  4.72326106],
#        [ 2.16687183,  5.82049867],
#        [-1.8430872 ,  1.99034585],
#        [-1.42634032,  7.10499664],
#        [-0.3148482 ,  4.1335951 ],
#        [-1.05456141,  7.12448381],
#        [-1.97526637,  7.49600592],
#        [-1.59960739,  7.98053076],
#        [ 0.9537243 ,  4.64645282],
#        [-0.38569793,  5.78811228],
#        [-0.02596621,  4.92577961],
#        [ 1.40457611, -0.2754758 ],
#        [-0.86963544,  2.92211638],
#        [-0.81360626,  8.18669438],
#        [-2.00582716,  2.02516467],
#        [ 1.80655858,  0.97558379],
#        [ 1.14289006,  5.08509856],
#        [-2.16009774,  8.46342603],
#        [ 0.56854833,  3.95332789],
#        [ 0.66640862,  4.06194513],
#        [ 1.50162764,  2.1267653 ],
#        [ 0.76186738,  4.94575244],
#        [-3.00135965,  2.53550306],
#        [-0.77246714,  0.72614053],
#        [-0.04011792,  5.07930469],
#        [ 1.22787325,  1.44293927],
#        [ 1.29307545,  3.42933812],
#        [ 1.11821099,  3.98236258],
#        [-1.2186512 ,  8.44978194],
#        [ 1.29051152,  0.62087824],
#        [ 2.20249345,  5.47927434],
#        [-1.25578071,  4.53471711],
#        [-1.11711292,  7.9125171 ],
#        [ 2.60712205,  1.93914064],
#        [ 2.39627451,  1.43919009],
#        [ 0.43830172,  4.0161448 ],
#        [-0.78142531,  3.18985425],
#        [ 2.81480417,  0.96770465],
#        [ 1.91929374,  4.15984746],
#        [-2.45278822,  2.66804846],
#        [-1.59564863,  3.07331661],
#        [-0.216736  ,  4.65530069],
#        [ 1.58510026,  4.40112734],
#        [ 1.09150494,  5.46720613],
#        [ 0.69794036,  4.4288665 ],
#        [ 2.60849852,  1.45346297],
#        [-1.89275698,  6.94081048],
#        [ 0.13742771,  3.16777298],
#        [-0.8262378 ,  2.82579629],
#        [ 1.02948386,  4.54576485],
#        [ 0.42061579,  4.1840797 ],
#        [-2.3153126 ,  1.74041426],
#        [-1.30729093,  2.20515019],
#        [-3.20258647,  3.01685979],
#        [ 1.87757882,  3.43984212],
#        [-2.0771741 ,  1.94662034],
#        [-2.00375057,  8.02594253],
#        [ 1.2774105 ,  3.42426669],
#        [-0.78329992,  3.38366193],
#        [ 1.80805715, -0.44313939],
#        [-1.90038045,  1.78435737],
#        [ 1.29814339,  3.75593925],
#        [-1.56216697,  5.39854557],
#        [-1.57620513,  2.83203804],
#        [-0.4988618 ,  8.96532218],
#        [ 1.10960887,  4.81181248],
#        [-0.88523024,  6.37166769],
#        [ 1.51410588,  4.6297568 ],
#        [-1.67942681,  2.60200265],
#        [-0.3278886 ,  4.67401313],
#        [ 1.96050262,  5.26569121],
#        [-1.45757213,  7.68966419],
#        [-0.43527853,  2.36632291],
#        [-0.67209649,  2.55517362],
#        [ 1.96073629,  0.3535211 ],
#        [ 3.25085516, -0.75832436],
#        [ 0.25043139,  4.34534364],
#        [-2.072204  ,  7.55550532],
#        [ 2.68432989,  0.52452838],
#        [ 2.03580662,  0.30723893],
#        [-2.93161648,  3.27862983],
#        [ 1.47478962, -0.2090275 ],
#        [-2.94173477,  3.2022677 ],
#        [ 0.26604148,  2.71915015],
#        [-0.19294627,  7.12952496],
#        [-1.08881562,  7.79497718],
#        [ 2.5146237 ,  5.48819916],
#        [ 1.01287689,  4.15404025],
#        [-1.44187164,  9.05006895],
#        [ 0.64537489,  3.70582348],
#        [ 0.50624368,  1.04868654],
#        [-0.96813829,  2.92089897],
#        [ 0.72702805,  4.3487196 ],
#        [ 1.94896306,  0.65943096],
#        [-1.15639975,  3.14115887],
#        [-1.02083204,  9.22959504],
#        [-1.98235366,  3.13380575],
#        [ 3.00569136,  1.15121775],
#        [ 0.04415021,  5.02444852],
#        [ 3.86271468,  0.86385794],
#        [-1.69170348,  7.45894989],
#        [-1.62428208,  7.66207484],
#        [-2.01665928,  7.20096613],
#        [-1.8314915 ,  7.99270594],
#        [-1.69242695,  3.62202539],
#        [-1.23024401,  3.03153171],
#        [-0.55817897,  5.71096474],
#        [ 2.8827859 ,  5.05937092],
#        [-1.5394497 ,  3.0466248 ],
#        [ 1.29971052,  0.56962391],
#        [ 0.36033722,  4.73518668],
#        [-1.91062866,  3.4141689 ],
#        [-2.07411273,  4.2455229 ],
#        [-0.31090812,  4.29355371],
#        [ 2.02384127, -0.03681114],
#        [ 2.18047275,  1.08340849],
#        [-1.41057325,  7.74755379],
#        [ 0.893695  ,  4.63226613],
#        [ 0.11966798,  5.14734871],
#        [-2.37060678,  3.57408053],
#        [ 1.1372926 ,  0.54740762],
#        [-0.34538052,  8.23226077],
#        [-0.83173322,  3.13937979],
#        [ 1.66781904,  3.71005531],
#        [-0.3711783 ,  7.64808737],
#        [ 0.62814724,  5.78319831],
#        [ 2.1334475 ,  1.3640266 ],
#        [ 0.91601879,  0.50300775],
#        [-2.88538867,  3.22770664],
#        [-2.10258752,  2.26748787],
#        [ 2.79207378,  3.14029479],
#        [ 3.78585628,  1.96688602],
#        [ 1.77207239, -0.20229737],
#        [ 1.07491911,  1.57315404],
#        [ 2.47031725,  5.02862305],
#        [-1.24135346,  8.25706338],
#        [-2.06268927,  7.77317621],
#        [ 2.97713277,  1.76135853],
#        [ 2.79195458,  1.15264578],
#        [ 1.88779063,  3.31592667],
#        [ 2.45026094,  0.80478051],
#        [ 2.2792072 ,  0.81914335],
#        [ 3.61999737,  1.20973832],
#        [-1.66227101,  7.05239613],
#        [-0.35364104,  3.59992381],
#        [-1.35309898,  8.74192392],
#        [ 0.89750806,  3.7730047 ],
#        [ 2.3745046 , -1.32041055],
#        [ 1.7357083 ,  1.19370837],
#        [-1.07747174,  6.86860109],
#        [-1.7906764 ,  8.87373665],
#        [-1.28481894,  8.01186614],
#        [ 1.94650776,  1.80717675],
#        [ 2.67269996,  1.55646698],
#        [ 0.25989683,  4.61330933],
#        [ 0.90872347,  7.77632028],
#        [-1.87964212,  2.69359787]])

# %% [markdown]
# Podemos ajustar estos puntos a un numero determinado de grupos:

# %%
# https://scikit-learn.org/stable/modules/clustering.html#k-means
k_medias = KMeans(n_clusters=4, random_state=0)
k_medias.fit(puntos)
idx_prediccion = k_medias.predict(puntos)
 
plt.scatter(x, y, c=idx_prediccion, s=50, alpha=0.7, cmap='viridis')
 
centroides = k_medias.cluster_centers_
plt.scatter(centroides[:, 0], centroides[:, 1], c='red', s=100);

# %% [markdown]
# Este es el procedimiento del algoritmo:

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1-05xoK1X6jPUlA-lRg-E2mSP7STLM-Me)

# %% [markdown]
# ¿Puedes probar a agrupar estos puntos en otro numero de grupos: 2, 3, 5 y 15 grupos?¿Que efecto tiene en la posicion de los centroides?¿Cual es el numero correcto de grupos?

# %%
# Tu codigo aqui:

# 2 grupos 
k_medias = KMeans(n_clusters=2, random_state=0)
k_medias.fit(puntos)
idx_prediccion = k_medias.predict(puntos)
 
plt.scatter(x, y, c=idx_prediccion, s=50, alpha=0.7, cmap='viridis')
 
centroides = k_medias.cluster_centers_
plt.scatter(centroides[:, 0], centroides[:, 1], c='red', s=100);

# %%
# 3 grupos 
k_medias = KMeans(n_clusters=3, random_state=0)
k_medias.fit(puntos)
idx_prediccion = k_medias.predict(puntos)
 
plt.scatter(x, y, c=idx_prediccion, s=50, alpha=0.7, cmap='viridis')
 
centroides = k_medias.cluster_centers_
plt.scatter(centroides[:, 0], centroides[:, 1], c='red', s=100);

# %%
# 5 grupos 
k_medias = KMeans(n_clusters=5, random_state=0)
k_medias.fit(puntos)
idx_prediccion = k_medias.predict(puntos)
 
plt.scatter(x, y, c=idx_prediccion, s=50, alpha=0.7, cmap='viridis')
 
centroides = k_medias.cluster_centers_
plt.scatter(centroides[:, 0], centroides[:, 1], c='red', s=100);

# %%
# 15 grupos 
k_medias = KMeans(n_clusters=15, random_state=0)
k_medias.fit(puntos)
idx_prediccion = k_medias.predict(puntos)
 
plt.scatter(x, y, c=idx_prediccion, s=50, alpha=0.7, cmap='viridis')
 
centroides = k_medias.cluster_centers_
plt.scatter(centroides[:, 0], centroides[:, 1], c='red', s=100);

# %% [markdown]
# Como se puede apreciar, se realizaron agrupaciones tanto de grupos de 2,3,5 y 15. Los centroides se fueron generando en base de la división de una agrupación a medida que aumentamos el número de agrupaciones, pero en si no se puede decir a piori que un grupo es correcto debido a que puede hay muchos factores que pueden afectar los diferentes grupos. Por tal motivo es recomendable utilizar un método menos visual para decidir el número de grupos con la clasificación más efectiva buscando la inercia de cada uno de los grupos.

# %% [markdown]
# Podemos utilizar un metodo menos visual para decidir el numero de grupos que nos ofrece la clasificacion mas efectiva:

# %%
inercias = []
 
for i in range(1, 11):
  k_medias = KMeans(n_clusters=i, random_state=0)
  k_medias.fit(puntos)
  inercias.append(k_medias.inertia_)
 
plt.plot(range(1, 11), inercias)
plt.xlabel('Numbero de Grupos')
plt.ylabel('Inercia');

# %% [markdown]
# Ya que el metodo visual no es muy mecanico, podemos encontrar la posicion del mejor valor en el codo mediante la doble derivacion:

# %%
pct_difs = np.diff(inercias)/np.array(inercias[1:])
pct_difs
# Out:
# array([-1.20820979, -0.90310861, -0.91804932, -0.12904541, -0.14077872,
#        -0.11760151, -0.14126267, -0.10352559, -0.10580101])

# %%
pct_dif_dif = np.diff(pct_difs)
pct_dif_dif
# Out:
# array([ 0.30510118, -0.01494072,  0.78900391, -0.01173331,  0.02317721,
#        -0.02366116,  0.03773707, -0.00227542])

# %%
mejor_codo = np.argmax(pct_dif_dif)+2
mejor_codo
# Out:
# 4

# %% [markdown]
# # Segmentacion de clientes

# %% [markdown]
# Datos adaptados de:
# https://github.com/jeffprosise/Machine-Learning/blob/master/Data/customers.csv

# %% [markdown]
# Este tipo de tecnicas se pueden utilizar para segmentar, por ejemplo, los clientes de una empresa para poder ofrecerles el mejor servicio personalizado posible:

# %%
import pandas as pd

archivo_clientes = '/content/sample_data/clientes.txt'
clientes = pd.read_csv(archivo_clientes, index_col='ID:Cliente')
clientes.head()
# Out:
#             Genero  Edad  Salario  Clasificacion_gasto
# ID:Cliente
# 1           Hombre    19       15                   39
# 2           Hombre    21       15                   81
# 3            Mujer    20       16                    6
# 4            Mujer    23       16                   77
# 5            Mujer    31       17                   40

# %% [markdown]
# Salario y Clasificacion de Gasto nos pueden indicar que clientes podrian estar interesados en aumentar su nivel de compras:

# %%
puntos = clientes[ ['Salario','Clasificacion_gasto'] ].values
x = puntos[:, 0]
y = puntos[:, 1]
 
plt.scatter(x, y, s=50, alpha=0.7)
plt.xlabel('Salario')
plt.ylabel('Gasto');

# %% [markdown]
# ¿En cuantos grupos podemos agruparlos? Visualmente parece que 5 grupos nos dan el menor numero de grupos que maximiza las diferencias entre los clientes de cada grupo.

# %%
k_medias = KMeans(n_clusters=5, random_state=0)
k_medias.fit(puntos)
idx_prediccion = k_medias.predict(puntos)
 
plt.scatter(x, y, c=idx_prediccion, s=50, alpha=0.7, cmap='viridis')
plt.xlabel('Salario')
plt.ylabel('Gasto')
 
centroides = k_medias.cluster_centers_
plt.scatter(centroides[:, 0], centroides[:, 1], c='red', s=100);

# %% [markdown]
# Hemos elegido 5 grupos por inspeccion visual del grafico. ¿Podrias demostrar que esta eleccion es correcta?

# %% [markdown]
# Para demostrar que la elección es correcta se debe de utilizar un método menos visual para decidir el número de grupos con la clasificación más efectiva buscando la inercia de una serie de grupos.

# %%
# Tu codigo aqui:

inercias = []
 
for i in range(1, 11):
  k_medias = KMeans(n_clusters=i, random_state=0)
  k_medias.fit(puntos)
  inercias.append(k_medias.inertia_)
 
plt.plot(range(1, 11), inercias)
plt.xlabel('Numbero de Grupos')
plt.ylabel('Inercia');

# %%
pct_difs = np.diff(inercias)/np.array(inercias[1:])
pct_difs
# Out:
# array([-0.48861892, -0.70537255, -0.44338596, -0.65764565, -0.19273912,
#        -0.23153626, -0.20577044, -0.14959482, -0.05272599])

# %%
pct_dif_dif = np.diff(pct_difs)
pct_dif_dif
# Out:
# array([-0.21675363,  0.26198659, -0.21425969,  0.46490653, -0.03879714,
#         0.02576582,  0.05617562,  0.09686883])

# %%
mejor_codo = np.argmax(pct_dif_dif)+2
mejor_codo
# Out:
# 5

# %% [markdown]
# Como podemos observar, el gráfico se vuelve lineal en el punto 5 lo cual nos indica que es el número de grupos es el más efectivo posible.

# %% [markdown]
# ¿Cuales son los clientes con mayor salario y menor gasto? Podemos predecir en que grupo apareceria un cliente que tenga un salario de 120 y un gasto de 20:

# %%
objetivo = k_medias.predict(np.array([[90, 10]]))[0]
objetivo
# Out:
# 3

# %% [markdown]
# Los clientes de este grupo de interes se pueden extraer de la serie de datos completa:

# %%
# Grupo de poco gastadores con altos ingresos:
clientes['Grupo'] = k_medias.predict(clientes[['Salario','Clasificacion_gasto']].values)
# Filtrado solo para estos clientes:
clientes[ clientes['Grupo'] == objetivo]
# Out:
#             Genero  Edad  Salario  Clasificacion_gasto  Grupo
# ID:Cliente
# 129         Hombre    59       71                   11      3
# 131         Hombre    47       71                    9      3
# 135         Hombre    20       73                    5      3
# 137          Mujer    44       73                    7      3
# 139         Hombre    19       74                   10      3
# 141          Mujer    57       75                    5      3
# 145         Hombre    25       77                   12      3
# 149          Mujer    34       78                   22      3
# 151         Hombre    43       78                   17      3
# 153          Mujer    44       78                   20      3
# 155          Mujer    47       78                   16      3
# 157         Hombre    37       78                    1      3
# 159         Hombre    34       78                    1      3
# 163         Hombre    19       81                    5      3
# 165         Hombre    50       85                   26      3
# 167         Hombre    42       86                   20      3
# 169          Mujer    36       87                   27      3
# 171         Hombre    40       87                   13      3
# 173         Hombre    36       87                   10      3
# 175          Mujer    52       88                   13      3
# 177         Hombre    58       88                   15      3
# 179         Hombre    59       93                   14      3
# 181          Mujer    37       97                   32      3
# 183         Hombre    46       98                   15      3
# 185          Mujer    41       99                   39      3
# 187          Mujer    54      101                   24      3
# 189          Mujer    41      103                   17      3
# 191          Mujer    34      103                   23      3

# %% [markdown]
# Orientando nuestros esfuerzos de marketing y ventas hacia estos clientes quizas maximicemos nuestra eficacia. Otro modelo podria entonces clasificar los clientes por susceptibilidad a nuestras ofertas.

# %% [markdown]
# # Clasificacion Multivariable

# %% [markdown]
# La clasificacion no esta limitada a dos variables (bivariable), sino que puede ser multivariable. Para ello, debemos primero modificar el formato de nuestros datos para hacer todas las variables comprensibles por la maquina:

# %%
from sklearn.preprocessing import LabelEncoder
 
df = clientes.copy()
codificador = LabelEncoder()
df['Genero'] = codificador.fit_transform(df['Genero'])
df.head()
# Out:
#             Genero  Edad  Salario  Clasificacion_gasto  Grupo
# ID:Cliente
# 1                0    19       15                   39      1
# 2                0    21       15                   81      4
# 3                1    20       16                    6      7
# 4                1    23       16                   77      4
# 5                1    31       17                   40      1

# %% [markdown]
# Usaremos 3 variables inicialmente, es el limite de variables que podemos representar facilmente en el espacio tridimensional:

# %%
puntos = df[['Edad', 'Salario', 'Clasificacion_gasto']].values
k_medias = KMeans(n_clusters=5, random_state=0)
k_medias.fit(puntos)
df['Grupo'] = k_medias.predict(puntos)
df.Grupo
# Out:
# ID:Cliente
# 1      0
# 2      4
# 3      0
# 4      4
# 5      0
#       ..
# 196    1
# 197    3
# 198    1
# 199    3
# 200    1
# Name: Grupo, Length: 200, dtype: int32

# %% [markdown]
# Generamos una visualizacion tridimensional:

# %%
from mpl_toolkits.mplot3d import Axes3D
colors = ['red', 'blue', 'black', 'orange', 'white']

df['color'] = df.Grupo.map({0:colors[0], 1:colors[1], 2:colors[2],
                        3:colors[3], 4:colors[4]})
fig = plt.figure(figsize=(26,6))

ax = fig.add_subplot(131, projection='3d')
ax.scatter(df.Edad, df.Salario, df.Clasificacion_gasto, c=df.color, s=15)
ax.set_xlabel('Edad')
ax.set_ylabel('Salario')
ax.set_zlabel('Clasificacion Gasto')
plt.show()

# %% [markdown]
# ¿Como son estos grupos? Inspeccionando sus valores medios ganamos algo mas de informacion:

# %%
resultados = pd.DataFrame(columns = ['Grupo',
                                     'Edad',
                                     'Ingresos Medios',
                                     'Gasto Medio'])
 
for i in range(len(k_medias.cluster_centers_)):
    edad = df[df['Grupo'] == i]['Edad'].mean()
    ingresos = df[df['Grupo'] == i]['Salario'].mean()
    gasto = df[df['Grupo'] == i]['Clasificacion_gasto'].mean()
 
    gdf = df[df['Grupo'] == i]
     
    resultados.loc[i] = ([i, edad, ingresos, gasto])
 
resultados.head()
# Out:
#    Grupo       Edad  Ingresos Medios  Gasto Medio
# 0    0.0  45.217391        26.304348    20.913043
# 1    1.0  32.692308        86.538462    82.128205
# 2    2.0  43.088608        55.291139    49.569620
# 3    3.0  40.666667        87.750000    17.583333
# 4    4.0  25.521739        26.304348    78.565217

# %%
k_medias.predict(np.array([[20, 20, 20]]))[0]
# Out:
# 0

# %% [markdown]
# # Actividad:

# %% [markdown]
# Utilizando el archivo de datos sobre propiedas en EEUU, ¿Que tipo de grupos puedes generar mediante aprendizaje no supervisado?¿Que aplicaciones o utilidades podriamos extraer de estos datos?

# %% [markdown]
# Los datos son los siguientes:

# %% [markdown]
# 'Avg. Area Income': Ingresos medios de los residentes en la localizacion.
# 'Avg. Area House Age': Antiguedad media de las casas en la ciudad.
# 'Avg. Area Number of Rooms': Media de habitaciones por casa en la zona.
# 'Avg. Area Number of Bedrooms': Media de dormitorios por casa en la zona.
# 'Area Population': Poblacion de la zona en la que se localiza la casa.
# 'Price': Precio de la casa.
# 'Address': Direccion postal de la casa.

# %%
# Tu codigo aqui:

import pandas as pd

archivo_usa_housing = '/content/sample_data/USA_Housing.csv'
usa_housing = pd.read_csv(archivo_usa_housing)
usa_housing.columns = ['avg_area_income', 'avg_area_house_age','avg_area_number_of_rooms', 'avg_area_number_of_bedrooms', 'area_population', 'price', 'address']
usa_housing.columns
usa_housing.head()
# Out:
#    avg_area_income  ...                                            address
# 0     79545.458574  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     79248.642455  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     61287.067179  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3     63345.240046  ...                          USS Barnett\nFPO AP 44820
# 4     59982.197226  ...                         USNS Raymond\nFPO AE 09386
#
# [5 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
 
df = usa_housing.copy()
codificador = LabelEncoder()
df['address'] = codificador.fit_transform(df['address'])
df.head()
# Out:
#    avg_area_income  avg_area_house_age  ...         price  address
# 0     79545.458574            5.682861  ...  1.059034e+06      962
# 1     79248.642455            6.002900  ...  1.505891e+06      863
# 2     61287.067179            5.865890  ...  1.058988e+06     4069
# 3     63345.240046            7.188236  ...  1.260617e+06     4794
# 4     59982.197226            5.040555  ...  6.309435e+05     4736
#
# [5 rows x 7 columns]

# %%
puntos = df[['avg_area_income', 'avg_area_house_age', 'avg_area_number_of_rooms']].values
k_medias = KMeans(n_clusters=3, random_state=0)
k_medias.fit(puntos)
df['Grupo'] = k_medias.predict(puntos)
df.Grupo
# Out:
# 0       0
# 1       0
# 2       1
# 3       2
# 4       1
#        ..
# 4995    1
# 4996    0
# 4997    2
# 4998    2
# 4999    2
# Name: Grupo, Length: 5000, dtype: int32

# %%
from mpl_toolkits.mplot3d import Axes3D
colors = ['red', 'blue', 'black', 'orange', 'white']

df['color'] = df.Grupo.map({0:colors[0], 1:colors[1], 2:colors[2],
                        3:colors[3], 4:colors[4]})
fig = plt.figure(figsize=(26,6))

ax = fig.add_subplot(131, projection='3d')
ax.scatter(df.avg_area_income, df.avg_area_house_age, df.avg_area_number_of_rooms, c=df.color, s=15)
ax.set_xlabel('Avg. Area Income')
ax.set_ylabel('Avg. Area House Age')
ax.set_zlabel('Avg. Area Number of Rooms')
plt.show()

# %%
resultados = pd.DataFrame(columns = ['Grupo',
                                     'avg_area_income',
                                     'avg_area_house_age',
                                     'avg_area_number_of_rooms'])
 
for i in range(len(k_medias.cluster_centers_)):
    x = df[df['Grupo'] == i]['avg_area_income'].mean()
    y = df[df['Grupo'] == i]['avg_area_house_age'].mean()
    z  = df[df['Grupo'] == i]['avg_area_number_of_rooms'].mean()
 
    gdf = df[df['Grupo'] == i]
     
    resultados.loc[i] = ([i, x, y, z])
 
resultados.head()
# Out:
#    Grupo  avg_area_income  avg_area_house_age  avg_area_number_of_rooms
# 0    0.0     86720.538073            5.981257                  6.941386
# 1    1.0     60041.748413            5.974963                  6.993583
# 2    2.0     68281.916674            5.963666                  7.001900
# 3    3.0     49467.571905            6.000223                  7.020389
# 4    4.0     76311.374040            5.984427                  6.974146

# %%
k_medias.predict(np.array([[20, 20, 20]]))[0]
# Out:
# 3
